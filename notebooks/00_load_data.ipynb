# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import pandas as pd

print("Libraries loaded.")
# Out:
# Libraries loaded.

# %%
spark = SparkSession.builder \
    .appName("ChicagoCrime_LoadData") \
    .master("spark://spark-master:7077") \
    .getOrCreate()

print("Spark initialized.")
# Out:
# Spark initialized.

# %%
df = spark.read.parquet("hdfs://namenode:9000/data/processed/chicago_crimes_clean.parquet")

print("Total records:", df.count())
df.show(5)
# Out:
# Total records: 8422096
# +--------+-----------+--------------------+------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# |      ID|Case Number|                Date|Primary Type|        Description|Location Description|Arrest|Domestic|Beat|District|Ward|Community Area|    Latitude|    Longitude|     crime_datetime|crime_year|crime_month|crime_day|crime_hour|crime_day_of_week|time_of_day|season|location_category|location_risk_weight|crime_category|crime_severity_level|crime_severity_weight|is_violent|is_night|was_arrest_made|is_domestic_incident|is_public_space|        risk_score|Year|
# +--------+-----------+--------------------+------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# |    1732|   HH621385|09/02/2002 07:58:...|    HOMICIDE|FIRST DEGREE MURDER|              STREET| false|   false| 712|       7|  16|            68|41.786353153|-87.651034795|2002-09-02 19:58:00|      2002|          9|        2|        19|                2|    EVENING|  FALL|   Public Outdoor|                 3.0| Violent Crime|             Level 3|                 10.0|      true|   false|          false|               false|           true| 7.967741935483872|2002|
# |12450317|   JE333988|08/04/2002 09:00:...|       THEFT|      FROM BUILDING|           RESIDENCE| false|   false|1614|      16|  41|            76|        null|         null|2002-08-04 09:00:00|      2002|          8|        4|         9|                1|    MORNING|SUMMER|      Residential|                 2.0|Property Crime|             Level 1|                  1.0|     false|   false|          false|               false|          false|1.5806451612903225|2002|
# |    1835|   HH741151|10/27/2002 06:12:...|    HOMICIDE|FIRST DEGREE MURDER|            BASEMENT| false|   false|1111|      11|  37|            23|41.899767079|-87.737137548|2002-10-27 06:12:00|      2002|         10|       27|         6|                1|    MORNING|  FALL|      Residential|                 2.0| Violent Crime|             Level 3|                 10.0|      true|   false|          false|               false|          false| 6.806451612903226|2002|
# |    1304|   HH103827|01/03/2002 12:17:...|    HOMICIDE|FIRST DEGREE MURDER|        CHA ELEVATOR| false|   false|1823|      18|  27|             8| 41.89652481|-87.639211587|2002-01-03 00:17:00|      2002|          1|        3|         0|                5|      NIGHT|WINTER|            Other|                 1.0| Violent Crime|             Level 3|                 10.0|      true|    true|          false|               false|          false| 7.387096774193549|2002|
# |    1900|    C153276|12/05/2002 01:50:...|    HOMICIDE|FIRST DEGREE MURDER|              STREET|  true|   false|1524|      15|  37|            25|41.895773675|-87.764072031|2002-12-05 13:50:00|      2002|         12|        5|        13|                5|  AFTERNOON|WINTER|   Public Outdoor|                 3.0| Violent Crime|             Level 3|                 10.0|      true|   false|           true|               false|           true| 7.967741935483872|2002|
# +--------+-----------+--------------------+------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# only showing top 5 rows

# %%
spark.stop()
