# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("check-processed")
    .master("spark://spark-master:7077")
    .getOrCreate()
)

path = "hdfs://namenode:9000/data/processed/chicago_crimes_clean.parquet"

df = spark.read.parquet(path)

df.printSchema()
df.show(10, truncate=False)  

print("Row count:", df.count())
# Out:
# root
#  |-- ID: string (nullable = true)
#  |-- Case Number: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Primary Type: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Location Description: string (nullable = true)
#  |-- Arrest: boolean (nullable = true)
#  |-- Domestic: boolean (nullable = true)
#  |-- Beat: integer (nullable = true)
#  |-- District: integer (nullable = true)
#  |-- Ward: integer (nullable = true)
#  |-- Community Area: integer (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- crime_datetime: timestamp (nullable = true)
#  |-- crime_year: integer (nullable = true)
#  |-- crime_month: integer (nullable = true)
#  |-- crime_day: integer (nullable = true)
#  |-- crime_hour: integer (nullable = true)
#  |-- crime_day_of_week: integer (nullable = true)
#  |-- time_of_day: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- location_category: string (nullable = true)
#  |-- location_risk_weight: double (nullable = true)
#  |-- crime_category: string (nullable = true)
#  |-- crime_severity_level: string (nullable = true)
#  |-- crime_severity_weight: double (nullable = true)
#  |-- is_violent: boolean (nullable = true)
#  |-- is_night: boolean (nullable = true)
#  |-- was_arrest_made: boolean (nullable = true)
#  |-- is_domestic_incident: boolean (nullable = true)
#  |-- is_public_space: boolean (nullable = true)
#  |-- risk_score: double (nullable = true)
#  |-- Year: integer (nullable = true)
#
# +--------+-----------+----------------------+---------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# |ID      |Case Number|Date                  |Primary Type   |Description        |Location Description|Arrest|Domestic|Beat|District|Ward|Community Area|Latitude    |Longitude    |crime_datetime     |crime_year|crime_month|crime_day|crime_hour|crime_day_of_week|time_of_day|season|location_category|location_risk_weight|crime_category|crime_severity_level|crime_severity_weight|is_violent|is_night|was_arrest_made|is_domestic_incident|is_public_space|risk_score        |Year|
# +--------+-----------+----------------------+---------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# |1732    |HH621385   |09/02/2002 07:58:00 PM|HOMICIDE       |FIRST DEGREE MURDER|STREET              |false |false   |712 |7       |16  |68            |41.786353153|-87.651034795|2002-09-02 19:58:00|2002      |9          |2        |19        |2                |EVENING    |FALL  |Public Outdoor   |3.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |false          |false               |true           |7.967741935483872 |2002|
# |12450317|JE333988   |08/04/2002 09:00:00 AM|THEFT          |FROM BUILDING      |RESIDENCE           |false |false   |1614|16      |41  |76            |null        |null         |2002-08-04 09:00:00|2002      |8          |4        |9         |1                |MORNING    |SUMMER|Residential      |2.0                 |Property Crime|Level 1             |1.0                  |false     |false   |false          |false               |false          |1.5806451612903225|2002|
# |1835    |HH741151   |10/27/2002 06:12:00 AM|HOMICIDE       |FIRST DEGREE MURDER|BASEMENT            |false |false   |1111|11      |37  |23            |41.899767079|-87.737137548|2002-10-27 06:12:00|2002      |10         |27       |6         |1                |MORNING    |FALL  |Residential      |2.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |false          |false               |false          |6.806451612903226 |2002|
# |1304    |HH103827   |01/03/2002 12:17:00 AM|HOMICIDE       |FIRST DEGREE MURDER|CHA ELEVATOR        |false |false   |1823|18      |27  |8             |41.89652481 |-87.639211587|2002-01-03 00:17:00|2002      |1          |3        |0         |5                |NIGHT      |WINTER|Other            |1.0                 |Violent Crime |Level 3             |10.0                 |true      |true    |false          |false               |false          |7.387096774193549 |2002|
# |1900    |C153276    |12/05/2002 01:50:00 PM|HOMICIDE       |FIRST DEGREE MURDER|STREET              |true  |false   |1524|15      |37  |25            |41.895773675|-87.764072031|2002-12-05 13:50:00|2002      |12         |5        |13        |5                |AFTERNOON  |WINTER|Public Outdoor   |3.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |true           |false               |true           |7.967741935483872 |2002|
# |1351    |HH177432   |02/09/2002 07:16:00 PM|HOMICIDE       |FIRST DEGREE MURDER|STREET              |true  |false   |1624|16      |45  |15            |41.954356038|-87.752279309|2002-02-09 19:16:00|2002      |2          |9        |19        |7                |EVENING    |WINTER|Public Outdoor   |3.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |true           |false               |true           |7.967741935483872 |2002|
# |1917196 |HH100031   |01/01/2002 12:05:00 AM|CRIMINAL DAMAGE|TO PROPERTY        |RESIDENCE           |false |true    |314 |3       |null|null          |41.783392267|-87.594711117|2002-01-01 00:05:00|2002      |1          |1        |0         |3                |NIGHT      |WINTER|Residential      |2.0                 |Property Crime|Level 2             |3.0                  |false     |true    |false          |true                |false          |4.774193548387097 |2002|
# |1375    |HH212130   |02/26/2002 09:00:00 AM|HOMICIDE       |FIRST DEGREE MURDER|AUTO                |true  |false   |824 |8       |16  |63            |41.787844269|-87.683870028|2002-02-26 09:00:00|2002      |2          |26       |9         |3                |MORNING    |WINTER|Other            |1.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |true           |false               |false          |6.225806451612904 |2002|
# |1917402 |HH100519   |01/01/2002 05:00:00 AM|CRIMINAL DAMAGE|TO PROPERTY        |CHA APARTMENT       |false |false   |1231|12      |null|null          |41.863953508|-87.659039529|2002-01-01 05:00:00|2002      |1          |1        |5         |3                |MORNING    |WINTER|Residential      |2.0                 |Property Crime|Level 2             |3.0                  |false     |false   |false          |false               |false          |2.741935483870968 |2002|
# |1412    |HH268318   |03/27/2002 12:30:00 PM|HOMICIDE       |FIRST DEGREE MURDER|APARTMENT           |true  |false   |421 |4       |7   |43            |41.754350905|-87.550585227|2002-03-27 12:30:00|2002      |3          |27       |12        |4                |AFTERNOON  |SPRING|Residential      |2.0                 |Violent Crime |Level 3             |10.0                 |true      |false   |true           |false               |false          |6.806451612903226 |2002|
# +--------+-----------+----------------------+---------------+-------------------+--------------------+------+--------+----+--------+----+--------------+------------+-------------+-------------------+----------+-----------+---------+----------+-----------------+-----------+------+-----------------+--------------------+--------------+--------------------+---------------------+----------+--------+---------------+--------------------+---------------+------------------+----+
# only showing top 10 rows
#
# Row count: 8422096
